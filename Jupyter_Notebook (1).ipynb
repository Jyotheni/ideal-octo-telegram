# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jyotheni**

# %% [markdown]
# _I'am intrested in data science because I enjoy statistical analysis, which led me to a career in data science_

# %% [markdown]
# ### This tutorial shows how to creat line plot

# %%
a = [-4, -3, -2, -1]
b = [5, 6, 7, 8]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(a,b)
plt.show()

# %% [markdown]
# ~~POINTS MARKED ON THE GRAPH~~
# 1. (-4, 5)
# 2. (-3, 6)
# 3. (-2, 7)
# 4. (-1, 8)
#
# ![istockphoto-1271311350-612x612.jpg](attachment:3f964510-da86-4346-8e8b-106545d297ec.jpg)
